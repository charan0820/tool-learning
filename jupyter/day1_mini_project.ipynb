# %% [markdown]
# # Student grade Calculator

# %%
name = "Charan"
marks = [85, 90, 78, 95, 88]

# %%
average = sum(marks) / len(marks)
average
# Out:
# 87.2

# %%
if average >= 90:
    grade = "A"
elif average >= 80:
    grade = "B"
else:
    grade = "C"

grade
# Out:
# 'B'

# %% [markdown]
# ## Result
#
# Average marks calculated and grade assigned.
