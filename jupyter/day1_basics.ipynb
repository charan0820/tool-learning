# %%
print("Hello jupyter")
a = 5
# Out:
# Hello jupyter

# %% [markdown]
# # My first jupyter notebook
#
# Learning jupyter fundamentals.

# %%
x = 10
y = 20

x + y
a * 2
# Out:
# 10

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def square(n):
    return n * n

# %%
square(8)
# Out:
# 64

# %% [markdown]
# ## Topics Learned
#
# - Variables
# - Loops
# - Functions
# - Markdown
# - Code Cells
